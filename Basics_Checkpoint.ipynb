# %%
import random as rnd

f = rnd.randint(1, 100)
r = int(input('Enter a number between 1 and 100: '))
Try = 1
while True:
    if r > f:
        print('Too high, try again.')
        r = int(input('Enter a number between 1 and 100: '))
        Try = Try + 1
    if r < f:
        print('Too low, try again.')
        r = int(input('Enter a number between 1 and 100: '))
        Try = Try + 1
    if(r==f) :
        print(f'YOU WON AT THE TRY NUMBER {Try}')
        break    
    if Try == 5:
        print(f'You reached the maximum number of tries, the number was {f}, better luck next time!')
        break
# Out:
# Too low, try again.
# Too low, try again.
# Too high, try again.
# Too high, try again.
# You reached the maximum number of tries, the number was 51, better luck next time!
